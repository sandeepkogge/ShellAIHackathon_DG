# %%
import shutil
import glob
import os
import pandas as pd
import joblib

# %%
reg = joblib.load("my_random_forest.joblib")
reg1 = joblib.load("my_random_forest1.joblib")
reg2 = joblib.load("my_random_forest2.joblib")
reg3 = joblib.load("my_random_forest3.joblib")

# %%
for i in range (1,301):
    dir_path = "{}{}{}".format('weather_data',i,'.csv')
    test = pd.read_csv(dir_path, sep = ",", encoding = "utf-8")
    test.loc[test['Total Cloud Cover [%]']< 0,'Total Cloud Cover [%]'] = 0
    test["Global CMP22 (vent/cor) [W/m^2] 1h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(60)
    test["Global CMP22 (vent/cor) [W/m^2] 2h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(120)
    test["Global CMP22 (vent/cor) [W/m^2] 3h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(180)
    test["Global CMP22 (vent/cor) [W/m^2] 4h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(240)
    test["Global CMP22 (vent/cor) [W/m^2] 5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(300)
    test["Global CMP22 (vent/cor) [W/m^2] 6h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(360)

    test["Global CMP22 (vent/cor) [W/m^2] 0.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(30)
    test["Global CMP22 (vent/cor) [W/m^2] 1.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(90)
    test["Global CMP22 (vent/cor) [W/m^2] 2.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(150)
    test["Global CMP22 (vent/cor) [W/m^2] 3.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(210)
    test["Global CMP22 (vent/cor) [W/m^2] 4.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(270)
    test["Global CMP22 (vent/cor) [W/m^2] 5.5h"] = test["Global CMP22 (vent/cor) [W/m^2]"].shift(330)
    
    test["Direct sNIP [W/m^2] 1h"] = test["Direct sNIP [W/m^2]"].shift(60)
    test["Direct sNIP [W/m^2] 2h"] = test["Direct sNIP [W/m^2]"].shift(120)
    test["Direct sNIP [W/m^2] 3h"] = test["Direct sNIP [W/m^2]"].shift(180)
    test["Direct sNIP [W/m^2] 4h"] = test["Direct sNIP [W/m^2]"].shift(240)
    test["Direct sNIP [W/m^2] 5h"] = test["Direct sNIP [W/m^2]"].shift(300)
    test["Direct sNIP [W/m^2] 6h"] = test["Direct sNIP [W/m^2]"].shift(360)

    test["Direct sNIP [W/m^2] 0.5h"] = test["Direct sNIP [W/m^2]"].shift(30)
    test["Direct sNIP [W/m^2] 1.5h"] = test["Direct sNIP [W/m^2]"].shift(90)
    test["Direct sNIP [W/m^2] 2.5h"] = test["Direct sNIP [W/m^2]"].shift(150)
    test["Direct sNIP [W/m^2] 3.5h"] = test["Direct sNIP [W/m^2]"].shift(210)
    test["Direct sNIP [W/m^2] 4.5h"] = test["Direct sNIP [W/m^2]"].shift(270)
    test["Direct sNIP [W/m^2] 5.5h"] = test["Direct sNIP [W/m^2]"].shift(330)
    
    test["Azimuth Angle [degrees] 1h"] = test["Azimuth Angle [degrees]"].shift(60)
    test["Azimuth Angle [degrees] 2h"] = test["Azimuth Angle [degrees]"].shift(120)
    test["Azimuth Angle [degrees] 3h"] = test["Azimuth Angle [degrees]"].shift(180)
    test["Azimuth Angle [degrees] 4h"] = test["Azimuth Angle [degrees]"].shift(240)
    test["Azimuth Angle [degrees] 5h"] = test["Azimuth Angle [degrees]"].shift(300)
    test["Azimuth Angle [degrees] 6h"] = test["Azimuth Angle [degrees]"].shift(360)

    test["Azimuth Angle [degrees] 0.5h"] = test["Azimuth Angle [degrees]"].shift(30)
    test["Azimuth Angle [degrees] 1.5h"] = test["Azimuth Angle [degrees]"].shift(90)
    test["Azimuth Angle [degrees] 2.5h"] = test["Azimuth Angle [degrees]"].shift(150)
    test["Azimuth Angle [degrees] 3.5h"] = test["Azimuth Angle [degrees]"].shift(210)
    test["Azimuth Angle [degrees] 4.5h"] = test["Azimuth Angle [degrees]"].shift(270)
    test["Azimuth Angle [degrees] 5.5h"] = test["Azimuth Angle [degrees]"].shift(330)
    
    test["Tower Dry Bulb Temp [deg C] 1h"] = test["Tower Dry Bulb Temp [deg C]"].shift(60)
    test["Tower Dry Bulb Temp [deg C] 2h"] = test["Tower Dry Bulb Temp [deg C]"].shift(120)
    test["Tower Dry Bulb Temp [deg C] 3h"] = test["Tower Dry Bulb Temp [deg C]"].shift(180)
    test["Tower Dry Bulb Temp [deg C] 4h"] = test["Tower Dry Bulb Temp [deg C]"].shift(240)
    test["Tower Dry Bulb Temp [deg C] 5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(300)
    test["Tower Dry Bulb Temp [deg C] 6h"] = test["Tower Dry Bulb Temp [deg C]"].shift(360)

    test["Tower Dry Bulb Temp [deg C] 0.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(30)
    test["Tower Dry Bulb Temp [deg C] 1.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(90)
    test["Tower Dry Bulb Temp [deg C] 2.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(150)
    test["Tower Dry Bulb Temp [deg C] 3.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(210)
    test["Tower Dry Bulb Temp [deg C] 4.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(270)
    test["Tower Dry Bulb Temp [deg C] 5.5h"] = test["Tower Dry Bulb Temp [deg C]"].shift(330)
    
    test["Tower Wet Bulb Temp [deg C] 1h"] = test["Tower Wet Bulb Temp [deg C]"].shift(60)
    test["Tower Wet Bulb Temp [deg C] 2h"] = test["Tower Wet Bulb Temp [deg C]"].shift(120)
    test["Tower Wet Bulb Temp [deg C] 3h"] = test["Tower Wet Bulb Temp [deg C]"].shift(180)
    test["Tower Wet Bulb Temp [deg C] 4h"] = test["Tower Wet Bulb Temp [deg C]"].shift(240)
    test["Tower Wet Bulb Temp [deg C] 5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(300)
    test["Tower Wet Bulb Temp [deg C] 6h"] = test["Tower Wet Bulb Temp [deg C]"].shift(360)

    test["Tower Wet Bulb Temp [deg C] 0.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(30)
    test["Tower Wet Bulb Temp [deg C] 1.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(90)
    test["Tower Wet Bulb Temp [deg C] 2.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(150)
    test["Tower Wet Bulb Temp [deg C] 3.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(210)
    test["Tower Wet Bulb Temp [deg C] 4.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(270)
    test["Tower Wet Bulb Temp [deg C] 5.5h"] = test["Tower Wet Bulb Temp [deg C]"].shift(330)
    
    test["Tower Dew Point Temp [deg C] 1h"] = test["Tower Dew Point Temp [deg C]"].shift(60)
    test["Tower Dew Point Temp [deg C] 2h"] = test["Tower Dew Point Temp [deg C]"].shift(120)
    test["Tower Dew Point Temp [deg C] 3h"] = test["Tower Dew Point Temp [deg C]"].shift(180)
    test["Tower Dew Point Temp [deg C] 4h"] = test["Tower Dew Point Temp [deg C]"].shift(240)
    test["Tower Dew Point Temp [deg C] 5h"] = test["Tower Dew Point Temp [deg C]"].shift(300)
    test["Tower Dew Point Temp [deg C] 6h"] = test["Tower Dew Point Temp [deg C]"].shift(360)

    test["Tower Dew Point Temp [deg C] 0.5h"] = test["Tower Dew Point Temp [deg C]"].shift(30)
    test["Tower Dew Point Temp [deg C] 1.5h"] = test["Tower Dew Point Temp [deg C]"].shift(90)
    test["Tower Dew Point Temp [deg C] 2.5h"] = test["Tower Dew Point Temp [deg C]"].shift(150)
    test["Tower Dew Point Temp [deg C] 3.5h"] = test["Tower Dew Point Temp [deg C]"].shift(210)
    test["Tower Dew Point Temp [deg C] 4.5h"] = test["Tower Dew Point Temp [deg C]"].shift(270)
    test["Tower Dew Point Temp [deg C] 5.5h"] = test["Tower Dew Point Temp [deg C]"].shift(330)
    
    test["Tower RH [%] 1h"] = test["Tower RH [%]"].shift(60)
    test["Tower RH [%] 2h"] = test["Tower RH [%]"].shift(120)
    test["Tower RH [%] 3h"] = test["Tower RH [%]"].shift(180)
    test["Tower RH [%] 4h"] = test["Tower RH [%]"].shift(240)
    test["Tower RH [%] 5h"] = test["Tower RH [%]"].shift(300)
    test["Tower RH [%] 6h"] = test["Tower RH [%]"].shift(360)

    test["Tower RH [%] 0.5h"] = test["Tower RH [%]"].shift(30)
    test["Tower RH [%] 1.5h"] = test["Tower RH [%]"].shift(90)
    test["Tower RH [%] 2.5h"] = test["Tower RH [%]"].shift(150)
    test["Tower RH [%] 3.5h"] = test["Tower RH [%]"].shift(210)
    test["Tower RH [%] 4.5h"] = test["Tower RH [%]"].shift(270)
    test["Tower RH [%] 5.5h"] = test["Tower RH [%]"].shift(330)
    
    test["Peak Wind Speed @ 6ft [m/s] 1h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(60)
    test["Peak Wind Speed @ 6ft [m/s] 2h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(120)
    test["Peak Wind Speed @ 6ft [m/s] 3h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(180)
    test["Peak Wind Speed @ 6ft [m/s] 4h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(240)
    test["Peak Wind Speed @ 6ft [m/s] 5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(300)
    test["Peak Wind Speed @ 6ft [m/s] 6h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(360)

    test["Peak Wind Speed @ 6ft [m/s] 0.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(30)
    test["Peak Wind Speed @ 6ft [m/s] 1.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(90)
    test["Peak Wind Speed @ 6ft [m/s] 2.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(150)
    test["Peak Wind Speed @ 6ft [m/s] 3.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(210)
    test["Peak Wind Speed @ 6ft [m/s] 4.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(270)
    test["Peak Wind Speed @ 6ft [m/s] 5.5h"] = test["Peak Wind Speed @ 6ft [m/s]"].shift(330)
    
    test["Avg Wind Direction @ 6ft [deg from N] 1h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(60)
    test["Avg Wind Direction @ 6ft [deg from N] 2h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(120)
    test["Avg Wind Direction @ 6ft [deg from N] 3h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(180)
    test["Avg Wind Direction @ 6ft [deg from N] 4h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(240)
    test["Avg Wind Direction @ 6ft [deg from N] 5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(300)
    test["Avg Wind Direction @ 6ft [deg from N] 6h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(360)

    test["Avg Wind Direction @ 6ft [deg from N] 0.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(30)
    test["Avg Wind Direction @ 6ft [deg from N] 1.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(90)
    test["Avg Wind Direction @ 6ft [deg from N] 2.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(150)
    test["Avg Wind Direction @ 6ft [deg from N] 3.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(210)
    test["Avg Wind Direction @ 6ft [deg from N] 4.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(270)
    test["Avg Wind Direction @ 6ft [deg from N] 5.5h"] = test["Avg Wind Direction @ 6ft [deg from N]"].shift(330)
    
    test["Station Pressure [mBar] 1h"] = test["Station Pressure [mBar]"].shift(60)
    test["Station Pressure [mBar] 2h"] = test["Station Pressure [mBar]"].shift(120)
    test["Station Pressure [mBar] 3h"] = test["Station Pressure [mBar]"].shift(180)
    test["Station Pressure [mBar] 4h"] = test["Station Pressure [mBar]"].shift(240)
    test["Station Pressure [mBar] 5h"] = test["Station Pressure [mBar]"].shift(300)
    test["Station Pressure [mBar] 6h"] = test["Station Pressure [mBar]"].shift(360)

    test["Station Pressure [mBar] 0.5h"] = test["Station Pressure [mBar]"].shift(30)
    test["Station Pressure [mBar] 1.5h"] = test["Station Pressure [mBar]"].shift(90)
    test["Station Pressure [mBar] 2.5h"] = test["Station Pressure [mBar]"].shift(150)
    test["Station Pressure [mBar] 3.5h"] = test["Station Pressure [mBar]"].shift(210)
    test["Station Pressure [mBar] 4.5h"] = test["Station Pressure [mBar]"].shift(270)
    test["Station Pressure [mBar] 5.5h"] = test["Station Pressure [mBar]"].shift(330)
    
    test["Precipitation (Accumulated) [mm] 1h"] = test["Precipitation (Accumulated) [mm]"].shift(60)
    test["Precipitation (Accumulated) [mm] 2h"] = test["Precipitation (Accumulated) [mm]"].shift(120)
    test["Precipitation (Accumulated) [mm] 3h"] = test["Precipitation (Accumulated) [mm]"].shift(180)
    test["Precipitation (Accumulated) [mm] 4h"] = test["Precipitation (Accumulated) [mm]"].shift(240)
    test["Precipitation (Accumulated) [mm] 5h"] = test["Precipitation (Accumulated) [mm]"].shift(300)
    test["Precipitation (Accumulated) [mm] 6h"] = test["Precipitation (Accumulated) [mm]"].shift(360)

    test["Precipitation (Accumulated) [mm] 0.5h"] = test["Precipitation (Accumulated) [mm]"].shift(30)
    test["Precipitation (Accumulated) [mm] 1.5h"] = test["Precipitation (Accumulated) [mm]"].shift(90)
    test["Precipitation (Accumulated) [mm] 2.5h"] = test["Precipitation (Accumulated) [mm]"].shift(150)
    test["Precipitation (Accumulated) [mm] 3.5h"] = test["Precipitation (Accumulated) [mm]"].shift(210)
    test["Precipitation (Accumulated) [mm] 4.5h"] = test["Precipitation (Accumulated) [mm]"].shift(270)
    test["Precipitation (Accumulated) [mm] 5.5h"] = test["Precipitation (Accumulated) [mm]"].shift(330)
    
    test["Snow Depth [cm] 1h"] = test["Snow Depth [cm]"].shift(60)
    test["Snow Depth [cm] 2h"] = test["Snow Depth [cm]"].shift(120)
    test["Snow Depth [cm] 3h"] = test["Snow Depth [cm]"].shift(180)
    test["Snow Depth [cm] 4h"] = test["Snow Depth [cm]"].shift(240)
    test["Snow Depth [cm] 5h"] = test["Snow Depth [cm]"].shift(300)
    test["Snow Depth [cm] 6h"] = test["Snow Depth [cm]"].shift(360)

    test["Snow Depth [cm] 0.5h"] = test["Snow Depth [cm]"].shift(30)
    test["Snow Depth [cm] 1.5h"] = test["Snow Depth [cm]"].shift(90)
    test["Snow Depth [cm] 2.5h"] = test["Snow Depth [cm]"].shift(150)
    test["Snow Depth [cm] 3.5h"] = test["Snow Depth [cm]"].shift(210)
    test["Snow Depth [cm] 4.5h"] = test["Snow Depth [cm]"].shift(270)
    test["Snow Depth [cm] 5.5h"] = test["Snow Depth [cm]"].shift(330)
    
    test["Moisture 1h"] = test["Moisture"].shift(60)
    test["Moisture 2h"] = test["Moisture"].shift(120)
    test["Moisture 3h"] = test["Moisture"].shift(180)
    test["Moisture 4h"] = test["Moisture"].shift(240)
    test["Moisture 5h"] = test["Moisture"].shift(300)
    test["Moisture 6h"] = test["Moisture"].shift(360)

    test["Moisture 0.5h"] = test["Moisture"].shift(30)
    test["Moisture 1.5h"] = test["Moisture"].shift(90)
    test["Moisture 2.5h"] = test["Moisture"].shift(150)
    test["Moisture 3.5h"] = test["Moisture"].shift(210)
    test["Moisture 4.5h"] = test["Moisture"].shift(270)
    test["Moisture 5.5h"] = test["Moisture"].shift(330)
    
    test["Albedo (CMP11) 1h"] = test["Albedo (CMP11)"].shift(60)
    test["Albedo (CMP11) 2h"] = test["Albedo (CMP11)"].shift(120)
    test["Albedo (CMP11) 3h"] = test["Albedo (CMP11)"].shift(180)
    test["Albedo (CMP11) 4h"] = test["Albedo (CMP11)"].shift(240)
    test["Albedo (CMP11) 5h"] = test["Albedo (CMP11)"].shift(300)
    test["Albedo (CMP11) 6h"] = test["Albedo (CMP11)"].shift(360)

    test["Albedo (CMP11) 0.5h"] = test["Albedo (CMP11)"].shift(30)
    test["Albedo (CMP11) 1.5h"] = test["Albedo (CMP11)"].shift(90)
    test["Albedo (CMP11) 2.5h"] = test["Albedo (CMP11)"].shift(150)
    test["Albedo (CMP11) 3.5h"] = test["Albedo (CMP11)"].shift(210)
    test["Albedo (CMP11) 4.5h"] = test["Albedo (CMP11)"].shift(270)
    test["Albedo (CMP11) 5.5h"] = test["Albedo (CMP11)"].shift(330)
    
    test = test.dropna()
    
    Xtest = test[['Global CMP22 (vent/cor) [W/m^2]',
    'Direct sNIP [W/m^2]',
    'Azimuth Angle [degrees]',
    'Tower Dry Bulb Temp [deg C]',
    'Tower Wet Bulb Temp [deg C]',
    'Tower Dew Point Temp [deg C]',
    'Tower RH [%]',
    'Total Cloud Cover [%]',
    'Peak Wind Speed @ 6ft [m/s]',
    'Avg Wind Direction @ 6ft [deg from N]',
    'Station Pressure [mBar]',
    'Precipitation (Accumulated) [mm]',
    'Snow Depth [cm]',
    'Moisture',
    'Albedo (CMP11)',
    'Global CMP22 (vent/cor) [W/m^2] 1h',
    'Global CMP22 (vent/cor) [W/m^2] 2h',
    'Global CMP22 (vent/cor) [W/m^2] 3h',
    'Global CMP22 (vent/cor) [W/m^2] 4h',
    'Global CMP22 (vent/cor) [W/m^2] 5h',
    'Global CMP22 (vent/cor) [W/m^2] 6h',
    'Global CMP22 (vent/cor) [W/m^2] 0.5h',
    'Global CMP22 (vent/cor) [W/m^2] 1.5h',
    'Global CMP22 (vent/cor) [W/m^2] 2.5h',
    'Global CMP22 (vent/cor) [W/m^2] 3.5h',
    'Global CMP22 (vent/cor) [W/m^2] 4.5h',
    'Global CMP22 (vent/cor) [W/m^2] 5.5h',
    'Direct sNIP [W/m^2] 1h',
    'Direct sNIP [W/m^2] 2h',
    'Direct sNIP [W/m^2] 3h',
    'Direct sNIP [W/m^2] 4h',
    'Direct sNIP [W/m^2] 5h',
    'Direct sNIP [W/m^2] 6h',
    'Direct sNIP [W/m^2] 0.5h',
    'Direct sNIP [W/m^2] 1.5h',
    'Direct sNIP [W/m^2] 2.5h',
    'Direct sNIP [W/m^2] 3.5h',
    'Direct sNIP [W/m^2] 4.5h',
    'Direct sNIP [W/m^2] 5.5h',
    'Azimuth Angle [degrees] 1h',
    'Azimuth Angle [degrees] 2h',
    'Azimuth Angle [degrees] 3h',
    'Azimuth Angle [degrees] 4h',
    'Azimuth Angle [degrees] 5h',
    'Azimuth Angle [degrees] 6h',
    'Azimuth Angle [degrees] 0.5h',
    'Azimuth Angle [degrees] 1.5h',
    'Azimuth Angle [degrees] 2.5h',
    'Azimuth Angle [degrees] 3.5h',
    'Azimuth Angle [degrees] 4.5h',
    'Azimuth Angle [degrees] 5.5h',
    'Tower Dry Bulb Temp [deg C] 1h',
    'Tower Dry Bulb Temp [deg C] 2h',
    'Tower Dry Bulb Temp [deg C] 3h',
    'Tower Dry Bulb Temp [deg C] 4h',
    'Tower Dry Bulb Temp [deg C] 5h',
    'Tower Dry Bulb Temp [deg C] 6h',
    'Tower Dry Bulb Temp [deg C] 0.5h',
    'Tower Dry Bulb Temp [deg C] 1.5h',
    'Tower Dry Bulb Temp [deg C] 2.5h',
    'Tower Dry Bulb Temp [deg C] 3.5h',
    'Tower Dry Bulb Temp [deg C] 4.5h',
    'Tower Dry Bulb Temp [deg C] 5.5h',
    'Tower Wet Bulb Temp [deg C] 1h',
    'Tower Wet Bulb Temp [deg C] 2h',
    'Tower Wet Bulb Temp [deg C] 3h',
    'Tower Wet Bulb Temp [deg C] 4h',
    'Tower Wet Bulb Temp [deg C] 5h',
    'Tower Wet Bulb Temp [deg C] 6h',
    'Tower Wet Bulb Temp [deg C] 0.5h',
    'Tower Wet Bulb Temp [deg C] 1.5h',
    'Tower Wet Bulb Temp [deg C] 2.5h',
    'Tower Wet Bulb Temp [deg C] 3.5h',
    'Tower Wet Bulb Temp [deg C] 4.5h',
    'Tower Wet Bulb Temp [deg C] 5.5h',
    'Tower Dew Point Temp [deg C] 1h',
    'Tower Dew Point Temp [deg C] 2h',
    'Tower Dew Point Temp [deg C] 3h',
    'Tower Dew Point Temp [deg C] 4h',
    'Tower Dew Point Temp [deg C] 5h',
    'Tower Dew Point Temp [deg C] 6h',
    'Tower Dew Point Temp [deg C] 0.5h',
    'Tower Dew Point Temp [deg C] 1.5h',
    'Tower Dew Point Temp [deg C] 2.5h',
    'Tower Dew Point Temp [deg C] 3.5h',
    'Tower Dew Point Temp [deg C] 4.5h',
    'Tower Dew Point Temp [deg C] 5.5h',
    'Tower RH [%] 1h',
    'Tower RH [%] 2h',
    'Tower RH [%] 3h',
    'Tower RH [%] 4h',
    'Tower RH [%] 5h',
    'Tower RH [%] 6h',
    'Tower RH [%] 0.5h',
    'Tower RH [%] 1.5h',
    'Tower RH [%] 2.5h',
    'Tower RH [%] 3.5h',
    'Tower RH [%] 4.5h',
    'Tower RH [%] 5.5h',
    'Peak Wind Speed @ 6ft [m/s] 1h',
    'Peak Wind Speed @ 6ft [m/s] 2h',
    'Peak Wind Speed @ 6ft [m/s] 3h',
    'Peak Wind Speed @ 6ft [m/s] 4h',
    'Peak Wind Speed @ 6ft [m/s] 5h',
    'Peak Wind Speed @ 6ft [m/s] 6h',
    'Peak Wind Speed @ 6ft [m/s] 0.5h',
    'Peak Wind Speed @ 6ft [m/s] 1.5h',
    'Peak Wind Speed @ 6ft [m/s] 2.5h',
    'Peak Wind Speed @ 6ft [m/s] 3.5h',
    'Peak Wind Speed @ 6ft [m/s] 4.5h',
    'Peak Wind Speed @ 6ft [m/s] 5.5h',
    'Avg Wind Direction @ 6ft [deg from N] 1h',
    'Avg Wind Direction @ 6ft [deg from N] 2h',
    'Avg Wind Direction @ 6ft [deg from N] 3h',
    'Avg Wind Direction @ 6ft [deg from N] 4h',
    'Avg Wind Direction @ 6ft [deg from N] 5h',
    'Avg Wind Direction @ 6ft [deg from N] 6h',
    'Avg Wind Direction @ 6ft [deg from N] 0.5h',
    'Avg Wind Direction @ 6ft [deg from N] 1.5h',
    'Avg Wind Direction @ 6ft [deg from N] 2.5h',
    'Avg Wind Direction @ 6ft [deg from N] 3.5h',
    'Avg Wind Direction @ 6ft [deg from N] 4.5h',
    'Avg Wind Direction @ 6ft [deg from N] 5.5h',
    'Station Pressure [mBar] 1h',
    'Station Pressure [mBar] 2h',
    'Station Pressure [mBar] 3h',
    'Station Pressure [mBar] 4h',
    'Station Pressure [mBar] 5h',
    'Station Pressure [mBar] 6h',
    'Station Pressure [mBar] 0.5h',
    'Station Pressure [mBar] 1.5h',
    'Station Pressure [mBar] 2.5h',
    'Station Pressure [mBar] 3.5h',
    'Station Pressure [mBar] 4.5h',
    'Station Pressure [mBar] 5.5h',
    'Precipitation (Accumulated) [mm] 1h',
    'Precipitation (Accumulated) [mm] 2h',
    'Precipitation (Accumulated) [mm] 3h',
    'Precipitation (Accumulated) [mm] 4h',
    'Precipitation (Accumulated) [mm] 5h',
    'Precipitation (Accumulated) [mm] 6h',
    'Precipitation (Accumulated) [mm] 0.5h',
    'Precipitation (Accumulated) [mm] 1.5h',
    'Precipitation (Accumulated) [mm] 2.5h',
    'Precipitation (Accumulated) [mm] 3.5h',
    'Precipitation (Accumulated) [mm] 4.5h',
    'Precipitation (Accumulated) [mm] 5.5h',
    'Snow Depth [cm] 1h',
    'Snow Depth [cm] 2h',
    'Snow Depth [cm] 3h',
    'Snow Depth [cm] 4h',
    'Snow Depth [cm] 5h',
    'Snow Depth [cm] 6h',
    'Snow Depth [cm] 0.5h',
    'Snow Depth [cm] 1.5h',
    'Snow Depth [cm] 2.5h',
    'Snow Depth [cm] 3.5h',
    'Snow Depth [cm] 4.5h',
    'Snow Depth [cm] 5.5h',
    'Moisture 1h',
    'Moisture 2h',
    'Moisture 3h',
    'Moisture 4h',
    'Moisture 5h',
    'Moisture 6h',
    'Moisture 0.5h',
    'Moisture 1.5h',
    'Moisture 2.5h',
    'Moisture 3.5h',
    'Moisture 4.5h',
    'Moisture 5.5h',
    'Albedo (CMP11) 1h',
    'Albedo (CMP11) 2h',
    'Albedo (CMP11) 3h',
    'Albedo (CMP11) 4h',
    'Albedo (CMP11) 5h',
    'Albedo (CMP11) 6h',
    'Albedo (CMP11) 0.5h',
    'Albedo (CMP11) 1.5h',
    'Albedo (CMP11) 2.5h',
    'Albedo (CMP11) 3.5h',
    'Albedo (CMP11) 4.5h',
    'Albedo (CMP11) 5.5h']]
    
    ypred = reg.predict(Xtest)
    ypred1 = reg1.predict(Xtest)
    ypred2 = reg2.predict(Xtest)
    ypred3 = reg3.predict(Xtest)
    
    test['y_pred'] = ypred
    test['y_pred1'] = ypred1
    test['y_pred2'] = ypred2
    test['y_pred3'] = ypred3
    
    test = test.tail(1)
    test.to_csv(dir_path, sep = ",", encoding = "utf-8")
