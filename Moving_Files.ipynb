# %%
import shutil
import glob
import os

dest_dir = "D:/_Personal/3_Shell/2_Outputs/test_compile"
dest_dir2 = "/home/flyingpizza/Pictures/"

for file in glob.glob(r'D:/_Personal/3_Shell/2_Outputs/dataset/test/1/*.csv'):
    print (file)
    shutil.move(file,dest_dir)

# %%
for i in range (2,301):
    dir_path = "{}{}{}".format('D:/_Personal/3_Shell/2_Outputs/dataset/test/',i,'/*.csv')
    dir_path_1 = "{}{}".format('D:/_Personal/3_Shell/2_Outputs/dataset/test/',i)
    os.chdir(dir_path_1)
    os.rename('weather_data.csv',"{}{}{}".format('weather_data',i,'.csv'))
    for file in glob.glob(dir_path):
        print (file)
        shutil.move(file,dest_dir)
# Out:
# D:/_Personal/3_Shell/2_Outputs/dataset/test/2\weather_data2.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/3\weather_data3.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/4\weather_data4.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/5\weather_data5.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/6\weather_data6.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/7\weather_data7.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/8\weather_data8.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/9\weather_data9.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/10\weather_data10.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/11\weather_data11.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/12\weather_data12.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/13\weather_data13.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/14\weather_data14.csv
# D:/_Personal/3_Shell/2_Outputs/dataset/test/15\weather_data15.csv
# ...
